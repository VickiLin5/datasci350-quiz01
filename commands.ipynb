# %% [markdown]
# # 1-3
# cd ~/Documents
# git clone https://github.com/VickiLin5/datasci350-quiz01.git
# cd datasci350-quiz01

# %% [markdown]
# # 4
# touch commands.ipynb

# %% [markdown]
# # 5
# git checkout -b feature-update

# %% [markdown]
# # 6
# mkdir reports

# %% [markdown]
# # 7
# cd reports
# touch summary.md

# %% [markdown]
# # 8
# echo "This document provides a summary of the project updates." > summary.md

# %% [markdown]
# # 9
# cd ..
# git add report

# %% [markdown]
# # 10
# git commit -m "Add reports directory"

# %% [markdown]
# # 11
# touch reports/file{1,2,3}.txt

# %% [markdown]
# # 12
# mv data/raw-data.csv data/input-data.csv

# %% [markdown]
# # 13
# mkdir scripts/backup && cp scripts/*.py scripts/backup/

# %% [markdown]
# # 14
# rm docs/documentation.md

# %% [markdown]
# # 15
# git add .
# git commit -m "Update project files"

# %% [markdown]
# # 16
# touch .gitignore

# %% [markdown]
# # 17 & 18
# echo -e "temp/\ndataset0?.csv" > .gitignore
# cat .gitignore

# %% [markdown]
# # 19
# git add .gitignore && git commit -m "Add .gitignore file"

# %% [markdown]
# # 20
# git checkout main
# git merge feature-update

# %% [markdown]
# # 21
